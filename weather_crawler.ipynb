# %%
import requests

url = 'https://www.cwb.gov.tw/V8/C/W/OBS_Station.html?ID=46692'
r = requests.get(url)
print(r.text)
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]> <html lang="zh-Hant-TW" class="ie8"> <![endif]-->
# <!--[if IE 9]> <html lang="zh-Hant-TW" class="ie9"> <![endif]-->
# <!--[if !IE]><!-->
# <html lang="zh-Hant-TW">
# <!--<![endif]-->
# <head>
#   <title>測站觀測資料 | 交通部中央氣象局</title>
#   <!-- Meta -->
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <meta name="description" content="">
#   <meta name="author" content="">
#   <!--Facebook_meta_begin-->
# ...

# %%
import requests

url = 'https://www.cwb.gov.tw/V8/C/W/Observe/MOD/24hr/46692.html'
r = requests.get(url)
print(r.text)
# Out:
#              <tr data-cstname="臺北" data-estname="Taipei" data-countyid="63">
# 				 <th scope="row" headers="time" class="is_show">02/26<br class="visible-md"> 13:30</th>
# 				 <td headers="temp" class="is_show"><span class="tem-C is-active">24.3</span><span class="tem-F is-hidden">76</span></td>
# 				 <td headers="weather" class="is_show"><img src="/V8/assets/img/weather_icons/weathers/svg_icon/day/07.svg" title="陰" alt="陰"></td>
# 				 <td headers="w-1"><span class="wind">東</span></td>
# 				 <td headers="w-2"><span class="wind_2 is-active">1.0</span><span class="wind_1 is-hidden">1</span></td>
# 				 <td headers="w-3"><span class="wind_2 is-active">-</span><span class="wind_1 is-hidden">-</span></td>
# 				 <td headers="visible-1">11-15</td><td headers="hum">70</td>
# 				 <td headers="pre">1009.1</td>
# 				 <td headers="rain">0.0</td>
# 				 <td headers="sunlight">0.3</td>
# 				 </tr><tr>
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.cwb.gov.tw/V8/C/W/Observe/MOD/24hr/46692.html'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')
trs = soup.find_all('tr')
print(trs)
# Out:
# [<tr data-countyid="63" data-cstname="臺北" data-estname="Taipei">
# <th class="is_show" headers="time" scope="row">02/26<br class="visible-md"/> 13:30</th>
# <td class="is_show" headers="temp"><span class="tem-C is-active">24.3</span><span class="tem-F is-hidden">76</span></td>
# <td class="is_show" headers="weather"><img alt="陰" src="/V8/assets/img/weather_icons/weathers/svg_icon/day/07.svg" title="陰"/></td>
# <td headers="w-1"><span class="wind">東</span></td>
# <td headers="w-2"><span class="wind_2 is-active">1.0</span><span class="wind_1 is-hidden">1</span></td>
# <td headers="w-3"><span class="wind_2 is-active">-</span><span class="wind_1 is-hidden">-</span></td>
# <td headers="visible-1">11-15</td><td headers="hum">70</td>
# <td headers="pre">1009.1</td>
# <td headers="rain">0.0</td>
# <td headers="sunlight">0.3</td>
# </tr>, <tr>
# <th class="is_show" headers="time" scope="row">02/26<br class="visible-md"/> 13:20</th>
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.cwb.gov.tw/V8/C/W/Observe/MOD/24hr/46692.html'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')
trs = soup.find_all('tr')
print(len(trs))
print(trs[0])
# Out:
# 150
# <tr data-countyid="63" data-cstname="臺北" data-estname="Taipei">
# <th class="is_show" headers="time" scope="row">02/26<br class="visible-md"/> 13:50</th>
# <td class="is_show" headers="temp"><span class="tem-C is-active">24.3</span><span class="tem-F is-hidden">76</span></td>
# <td class="is_show" headers="weather"><img alt="陰" src="/V8/assets/img/weather_icons/weathers/svg_icon/day/07.svg" title="陰"/></td>
# <td headers="w-1"><span class="wind">西北</span></td>
# <td headers="w-2"><span class="wind_2 is-active">1.5</span><span class="wind_1 is-hidden">1</span></td>
# <td headers="w-3"><span class="wind_2 is-active">-</span><span class="wind_1 is-hidden">-</span></td>
# <td headers="visible-1">11-15</td><td headers="hum">70</td>
# <td headers="pre">1008.9</td>
# <td headers="rain">0.0</td>
# <td headers="sunlight">0.3</td>
# </tr>

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.cwb.gov.tw/V8/C/W/Observe/MOD/24hr/46692.html'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')
tr = soup.find('tr')
print(tr)
# Out:
# <tr data-countyid="63" data-cstname="臺北" data-estname="Taipei">
# <th class="is_show" headers="time" scope="row">02/26<br class="visible-md"/> 13:50</th>
# <td class="is_show" headers="temp"><span class="tem-C is-active">24.3</span><span class="tem-F is-hidden">76</span></td>
# <td class="is_show" headers="weather"><img alt="陰" src="/V8/assets/img/weather_icons/weathers/svg_icon/day/07.svg" title="陰"/></td>
# <td headers="w-1"><span class="wind">西北</span></td>
# <td headers="w-2"><span class="wind_2 is-active">1.5</span><span class="wind_1 is-hidden">1</span></td>
# <td headers="w-3"><span class="wind_2 is-active">-</span><span class="wind_1 is-hidden">-</span></td>
# <td headers="visible-1">11-15</td><td headers="hum">70</td>
# <td headers="pre">1008.9</td>
# <td headers="rain">0.0</td>
# <td headers="sunlight">0.3</td>
# </tr>

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.cwb.gov.tw/V8/C/W/Observe/MOD/24hr/46692.html'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')
tr = soup.find('tr')
print(tr.find(headers="time"))
print(tr.find(headers="temp"))
print(tr.find(headers="hum"))
print(tr.find(headers="rain"))
# Out:
# <th class="is_show" headers="time" scope="row">02/26<br class="visible-md"/> 13:50</th>
# <td class="is_show" headers="temp"><span class="tem-C is-active">24.3</span><span class="tem-F is-hidden">76</span></td>
# <td headers="hum">70</td>
# <td headers="rain">0.0</td>

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.cwb.gov.tw/V8/C/W/Observe/MOD/24hr/46692.html'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')
tr = soup.find('tr')
print(f'時間： {tr.find(headers="time").text}')
print(f'溫度： {tr.find(headers="temp").find("span").text}')
print(f'濕度： {tr.find(headers="hum").text}')
print(f'雨量： {tr.find(headers="rain").text}')
# Out:
# 時間： 02/26 14:00
# 溫度： 24.0
# 濕度： 72
# 雨量： 0.0
